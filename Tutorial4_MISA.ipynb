# %% [markdown]
# **Tutorial # 4 - Unsupervised abnormality detection**
#
# Goals:
#
# 1.   Train an autoencoder in an unsupervised fashion with 'normal' cases
# 2.   Test on 'abnormal' case to determine whether normality was learnt
# 3.   Are there any other strategies to detect abnormalities?

# %% [markdown]
# **Import libraries**

# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt # plotting purposes

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# **Define parameters**

# %%
# dataset parameters
FNAME_PATTERN = 'drive/MyDrive/iSeg2019-Training/subject-{}-{}.hdr'
N_VOLUMES = 10
IMAGE_SIZE = (144, 192, 256)

# network parameters
N_CLASSES = 1
N_INPUT_CHANNELS = 1
PATCH_SIZE = (32, 32)
PATCH_STRIDE = (32, 32)

# training, validation, test parameters
TRAINING_VOLUMES = [0, 1, 2, 3, 4, 5, 6]
VALIDATION_VOLUMES = [7, 9]

# data preparation parameters
CONTENT_THRESHOLD = 0.3

# training parameters
N_EPOCHS = 100
BATCH_SIZE = 32
PATIENCE = 20
MODEL_FNAME_PATTERN = 'model.h5'
OPTIMISER = 'Adam'
LOSS = 'MSE'

# %% [markdown]
# **Mount drive**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Define SegNet architecture**

# %%
def get_segnet(img_size=PATCH_SIZE, n_classes=N_CLASSES, n_input_channels=N_INPUT_CHANNELS, scale=1):
    inputs = keras.Input(shape=img_size + (n_input_channels, ))

    # Encoding path
    conv1 = layers.Conv2D(32*scale, (3, 3), padding="same", activation='relu')(inputs)
    max1 = layers.MaxPooling2D((2, 2))(conv1)
    drop1 = layers.Dropout(rate=0.3)(max1, training=True)

    conv2 = layers.Conv2D(64*scale, (3, 3), padding="same", activation='relu')(drop1)
    max2 = layers.MaxPooling2D((2, 2))(conv2)
    drop2 = layers.Dropout(rate=0.3)(max2, training=True)

    conv3 = layers.Conv2D(128*scale, (3, 3), padding="same", activation='relu')(drop2)
    max3 = layers.MaxPooling2D((2, 2))(conv3)
    drop3 = layers.Dropout(rate=0.3)(max3, training=True)

    lat = layers.Conv2D(256*scale, (3, 3), padding="same", activation='relu')(drop3)
    drop4 = layers.Dropout(rate=0.3)(lat, training=True)

    # Decoding path
    up1 = layers.UpSampling2D((2, 2))(drop4)
    conv4 = layers.Conv2D(128*scale, (3, 3), padding="same", activation='relu')(up1)
    drop5 = layers.Dropout(rate=0.3)(conv4, training=True)
    
    up2 = layers.UpSampling2D((2, 2))(drop5)
    conv5 = layers.Conv2D(64*scale, (3, 3), padding="same", activation='relu')(up2)
    drop6 = layers.Dropout(rate=0.3)(conv5, training=True)
    
    up3 = layers.UpSampling2D((2, 2))(drop6)
    conv6 = layers.Conv2D(32*scale, (3, 3), padding="same", activation='relu')(up3)
    drop7 = layers.Dropout(rate=0.3)(conv6, training=True)

    outputs = layers.Conv2D(n_classes, (1, 1), activation="linear")(drop7)

    model = keras.Model(inputs, outputs)

    return model

# %% [markdown]
# **Load data**

# %%
def load_data(n_volumes=N_VOLUMES, image_size=IMAGE_SIZE, fname_pattern=FNAME_PATTERN) :
  T1_volumes = np.zeros((n_volumes, *image_size, 1))
  T2_volumes = np.zeros((n_volumes, *image_size, 1))
  labels = np.zeros((n_volumes, *image_size, 1))
  for i in range(n_volumes) :
    img_data = nib.load(fname_pattern.format(i+1, 'T1'))
    T1_volumes[i] = img_data.get_fdata()

    img_data = nib.load(fname_pattern.format(i+1, 'T2'))
    T2_volumes[i] = img_data.get_fdata()

    seg_data = nib.load(fname_pattern.format(i+1, 'label'))
    labels[i] = seg_data.get_fdata()

  return (T1_volumes, T2_volumes, labels)

# %%
(T1_volumes, _, labels) = load_data()

# %% [markdown]
# **Split into training, validation and testing**

# %%
training_volumes_T1 = T1_volumes[TRAINING_VOLUMES]
training_labels = labels[TRAINING_VOLUMES]

validation_volumes_T1 = T1_volumes[VALIDATION_VOLUMES]
validation_labels = labels[VALIDATION_VOLUMES]

# %% [markdown]
# **Pre-process data**

# %%
def z_score_standardisation(x, avg, std):
  return (x-avg)/std

ref_avg = training_volumes_T1[training_labels!=0].mean()
ref_std = training_volumes_T1[training_labels!=0].std()

training_volumes_T1 = z_score_standardisation(training_volumes_T1, ref_avg, ref_std)
validation_volumes_T1 = z_score_standardisation(validation_volumes_T1, ref_avg, ref_std)

# %% [markdown]
# **Extract *useful* patches**
#
# This step is fundamental, we want to provide the network with useful information

# %%
def extract_patches(x, patch_size, patch_stride) :
  return tf.image.extract_patches(
    x,
    sizes=[1, *patch_size, 1],
    strides=[1, *patch_stride, 1],
    rates=[1, 1, 1, 1],
    padding='SAME', name=None)

# %%
def extract_useful_patches(
    volumes, labels,
    image_size=IMAGE_SIZE,
    patch_size=PATCH_SIZE,
    stride=PATCH_STRIDE,
    threshold=CONTENT_THRESHOLD,
    num_classes=N_CLASSES) :
  volumes = volumes.reshape([-1, image_size[1], image_size[2], 1])
  labels = labels.reshape([-1, image_size[1], image_size[2], 1])

  vol_patches = extract_patches(volumes, patch_size, stride).numpy()
  seg_patches = extract_patches(labels, patch_size, stride).numpy()

  vol_patches = vol_patches.reshape([-1, *patch_size, 1])
  seg_patches = seg_patches.reshape([-1, *patch_size, ])

  foreground_mask = seg_patches != 0

  useful_patches = foreground_mask.sum(axis=(1, 2)) > threshold * np.prod(patch_size)

  vol_patches = vol_patches[useful_patches]
  
  return vol_patches

# %%
# extract patches from training set
training_patches_T1 = extract_useful_patches(training_volumes_T1, training_labels)

# extract patches from validation set
validation_patches_T1 = extract_useful_patches(validation_volumes_T1, validation_labels)

# %% [markdown]
# **Train network**

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=PATIENCE),
    tf.keras.callbacks.ModelCheckpoint(filepath=MODEL_FNAME_PATTERN)
]

segnet = get_segnet()
segnet.compile(optimizer=OPTIMISER, loss=LOSS)
segnet.fit(
    x=training_patches_T1,
    y=training_patches_T1,
    validation_data=(validation_patches_T1, validation_patches_T1),
    epochs=N_EPOCHS,
    callbacks=my_callbacks,
    verbose=1)
# Out:
# Epoch 1/100
# 213/213 [==============================] - 11s 12ms/step - loss: 0.4471 - val_loss: 0.2044
# Epoch 2/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.2621 - val_loss: 0.1720
# Epoch 3/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.2307 - val_loss: 0.1631
# Epoch 4/100
# 213/213 [==============================] - 2s 8ms/step - loss: 0.2179 - val_loss: 0.1537
# Epoch 5/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.2087 - val_loss: 0.1487
# Epoch 6/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.2003 - val_loss: 0.1472
# Epoch 7/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1957 - val_loss: 0.1444
# Epoch 8/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1904 - val_loss: 0.1397
# Epoch 9/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1865 - val_loss: 0.1377
# Epoch 10/100
# 213/213 [==============================] - 2s 8ms/step - loss: 0.1810 - val_loss: 0.1365
# Epoch 11/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1794 - val_loss: 0.1360
# Epoch 12/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1773 - val_loss: 0.1355
# Epoch 13/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1754 - val_loss: 0.1324
# Epoch 14/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1721 - val_loss: 0.1327
# Epoch 15/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1709 - val_loss: 0.1292
# Epoch 16/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1706 - val_loss: 0.1309
# Epoch 17/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1696 - val_loss: 0.1292
# Epoch 18/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1674 - val_loss: 0.1267
# Epoch 19/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1664 - val_loss: 0.1328
# Epoch 20/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1652 - val_loss: 0.1268
# Epoch 21/100
# 213/213 [==============================] - 2s 11ms/step - loss: 0.1638 - val_loss: 0.1261
# Epoch 22/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1635 - val_loss: 0.1269
# Epoch 23/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1626 - val_loss: 0.1238
# Epoch 24/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1615 - val_loss: 0.1236
# Epoch 25/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1604 - val_loss: 0.1249
# Epoch 26/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1606 - val_loss: 0.1232
# Epoch 27/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1601 - val_loss: 0.1235
# Epoch 28/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1594 - val_loss: 0.1236
# Epoch 29/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1588 - val_loss: 0.1206
# Epoch 30/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1588 - val_loss: 0.1231
# Epoch 31/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1582 - val_loss: 0.1219
# Epoch 32/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1579 - val_loss: 0.1221
# Epoch 33/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1573 - val_loss: 0.1220
# Epoch 34/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1563 - val_loss: 0.1235
# Epoch 35/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1557 - val_loss: 0.1197
# Epoch 36/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1554 - val_loss: 0.1228
# Epoch 37/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1553 - val_loss: 0.1226
# Epoch 38/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1554 - val_loss: 0.1199
# Epoch 39/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1547 - val_loss: 0.1217
# Epoch 40/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1545 - val_loss: 0.1193
# Epoch 41/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1537 - val_loss: 0.1187
# Epoch 42/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1539 - val_loss: 0.1188
# Epoch 43/100
# 213/213 [==============================] - 2s 11ms/step - loss: 0.1537 - val_loss: 0.1180
# Epoch 44/100
# 213/213 [==============================] - 2s 10ms/step - loss: 0.1533 - val_loss: 0.1183
# Epoch 45/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1525 - val_loss: 0.1176
# Epoch 46/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1517 - val_loss: 0.1172
# Epoch 47/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1526 - val_loss: 0.1182
# Epoch 48/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1520 - val_loss: 0.1166
# Epoch 49/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1516 - val_loss: 0.1188
# Epoch 50/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1509 - val_loss: 0.1168
# Epoch 51/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1509 - val_loss: 0.1174
# Epoch 52/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1501 - val_loss: 0.1162
# Epoch 53/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1504 - val_loss: 0.1173
# Epoch 54/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1518 - val_loss: 0.1171
# Epoch 55/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1502 - val_loss: 0.1206
# Epoch 56/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1498 - val_loss: 0.1156
# Epoch 57/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1491 - val_loss: 0.1165
# Epoch 58/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1497 - val_loss: 0.1166
# Epoch 59/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1503 - val_loss: 0.1173
# Epoch 60/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1499 - val_loss: 0.1171
# Epoch 61/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1494 - val_loss: 0.1162
# Epoch 62/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1486 - val_loss: 0.1152
# Epoch 63/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1485 - val_loss: 0.1154
# Epoch 64/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1484 - val_loss: 0.1156
# Epoch 65/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1481 - val_loss: 0.1155
# Epoch 66/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1481 - val_loss: 0.1157
# Epoch 67/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1485 - val_loss: 0.1161
# Epoch 68/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1477 - val_loss: 0.1154
# Epoch 69/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1474 - val_loss: 0.1152
# Epoch 70/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1483 - val_loss: 0.1151
# Epoch 71/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1475 - val_loss: 0.1150
# Epoch 72/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1469 - val_loss: 0.1157
# Epoch 73/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1468 - val_loss: 0.1144
# Epoch 74/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1481 - val_loss: 0.1150
# Epoch 75/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1472 - val_loss: 0.1151
# Epoch 76/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1465 - val_loss: 0.1156
# Epoch 77/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1462 - val_loss: 0.1149
# Epoch 78/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1464 - val_loss: 0.1147
# Epoch 79/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1465 - val_loss: 0.1150
# Epoch 80/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1465 - val_loss: 0.1152
# Epoch 81/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1461 - val_loss: 0.1135
# Epoch 82/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1481 - val_loss: 0.1147
# Epoch 83/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1463 - val_loss: 0.1169
# Epoch 84/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1461 - val_loss: 0.1144
# Epoch 85/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1456 - val_loss: 0.1139
# Epoch 86/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1457 - val_loss: 0.1147
# Epoch 87/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1467 - val_loss: 0.1152
# Epoch 88/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1459 - val_loss: 0.1168
# Epoch 89/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1452 - val_loss: 0.1140
# Epoch 90/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1462 - val_loss: 0.1139
# Epoch 91/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1454 - val_loss: 0.1144
# Epoch 92/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1457 - val_loss: 0.1139
# Epoch 93/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1446 - val_loss: 0.1130
# Epoch 94/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1457 - val_loss: 0.1146
# Epoch 95/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1447 - val_loss: 0.1133
# Epoch 96/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1489 - val_loss: 0.1166
# Epoch 97/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1459 - val_loss: 0.1155
# Epoch 98/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1448 - val_loss: 0.1145
# Epoch 99/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1448 - val_loss: 0.1146
# Epoch 100/100
# 213/213 [==============================] - 2s 9ms/step - loss: 0.1446 - val_loss: 0.1159

# %% [markdown]
# **Load best model**

# %%
segnet = get_segnet(
    img_size=(IMAGE_SIZE[1], IMAGE_SIZE[2]),
    n_classes=N_CLASSES,
    n_input_channels=N_INPUT_CHANNELS)

segnet.compile(optimizer=OPTIMISER, loss=LOSS)
segnet.load_weights('model.h5')

# %% [markdown]
# **Prepare test data**

# %%
test_case = 'drive/MyDrive/iSeg2019-Training/subject-{}-{}.nii'.format(9, 'T1-mod')

testing_volumes_T1 = nib.load(test_case).get_fdata()
testing_volumes_T1 = z_score_standardisation(testing_volumes_T1, ref_avg, ref_std)

# %%
testing_volumes_T1_processed = testing_volumes_T1.reshape([-1, IMAGE_SIZE[1], IMAGE_SIZE[2], 1])

# %% [markdown]
# **Predict labels for test data**

# %%
prediction = segnet.predict(x=testing_volumes_T1_processed)
difference = testing_volumes_T1_processed - prediction

plt.imshow(difference[:, :, 149, 0])
# Out:
# 5/5 [==============================] - 0s 99ms/step

# %%
N_RUNS = 10
predictions = np.zeros(IMAGE_SIZE+(N_CLASSES, N_RUNS, ))
for run in range(N_RUNS) :
  predictions[..., run] = segnet.predict(x=testing_volumes_T1_processed)

mean_prediction = predictions.mean(axis=-1)
std_prediction = predictions.std(axis=-1)
# Out:
# 5/5 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 83ms/step
# 5/5 [==============================] - 0s 83ms/step

# %%
plt.imshow(std_prediction[:, :, 149, 0])
plt.colorbar()
